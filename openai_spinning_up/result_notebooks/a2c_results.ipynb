# %% [markdown]
# # Results for Synchronous Advantage Actor Critc (A2C)

# %%
cd ..
# Out:
# /home/janus/repos/rl-zoo/openai_spinning_up

# %%
# %load_ext autoreload
# %autoreload 2

import gym
from src.algorithms.a2c import A2C
from src.visualization.visualization import visualize_episode_return, visualize_epoch_state_value_loss, visualize_epoch_entropy
import numpy as np
import pybullet_envs

# %% [markdown]
# ## CartPole-v0

# %%
env = gym.make('CartPole-v0')
n_runs = 5
a2c_agent = A2C(env, 'CartPole-v0')
episode_returns = []
for i in range(n_runs):
    print('Started run:', i)
    ep_ret = a2c_agent.train(n_epochs=1500)
    episode_returns.append(ep_ret)
# Out:
# Started run: 0
# HBox(children=(IntProgress(value=0, max=1500), HTML(value='')))
# Started run: 1
# HBox(children=(IntProgress(value=0, max=1500), HTML(value='')))
# Started run: 2
# HBox(children=(IntProgress(value=0, max=1500), HTML(value='')))
# Started run: 3
# HBox(children=(IntProgress(value=0, max=1500), HTML(value='')))
# Started run: 4
# HBox(children=(IntProgress(value=0, max=1500), HTML(value='')))

# %%
colors = np.random.rand(n_runs,3)
visualize_episode_return(episode_returns, colors)

# %% [markdown]
# ## LunarLander-v2

# %%
env = gym.make('LunarLander-v2')
n_runs = 3
a2c_agent = A2C(env, 'LunarLander-v2')
episode_returns = []
for i in range(n_runs):
    print('Started run:', i)
    ep_ret = a2c_agent.train(n_epochs=3000)
    episode_returns.append(ep_ret)
# Out:
# Started run: 0
# HBox(children=(IntProgress(value=0, max=3000), HTML(value='')))
# Started run: 1
# HBox(children=(IntProgress(value=0, max=3000), HTML(value='')))
# Started run: 2
# HBox(children=(IntProgress(value=0, max=3000), HTML(value='')))

# %%
colors = np.random.rand(n_runs,3)
visualize_episode_return(episode_returns, colors)
