# %% [markdown]
# # Results for Vanilla Policy Gradient

# %%
# change current directory to the root folder of the project

# %%
cd ../..
# Out:
# /home/research/repos/rl-zoo

# %%
# %load_ext autoreload
# %autoreload 2

import gym
from src.vpg import VPG
from src.visualization import visualize_episode_return

# %% [markdown]
# ## CartPole-v0

# %%
env = gym.make('CartPole-v0')
n_runs = 1
vpg_agent = VPG(env)
episode_returns = []
for i in range(n_runs):
    episode_returns.append(vpg_agent.train(n_epochs=5))

# %%
visualize_episode_return(episode_returns)

# %% [markdown]
# ## LunarLander-v2

# %% [markdown]
# ## Half-Chetaah-BulletEnv

# %% [markdown]
# ## Pendulum-v0

# %%
env = gym.make('Pendulum-v0')
n_runs = 1
vpg_agent = VPG(env)
episode_returns = []
for i in range(n_runs):
    episode_returns.append(vpg_agent.train(n_epochs=400))
# Out:
# 0 -1349.3906699262511 -1638.4406058584063 -1167.4515763042841
# 1 -1283.940592617339 -1380.163737596456 -1202.3960307360142
# 2 -1269.9686490846302 -1549.2825050169897 -1178.0296354003008
# 3 -1264.304727204444 -1765.1994931265015 -1150.3436667134988
# 4 -1253.851138060968 -1788.8103757221597 -1120.092893666032
# 5 -1229.3017975094128 -1482.864454173874 -1140.6552652509513
# 6 -1222.1293890628394 -1435.5268848736362 -1137.2304602328838
# 7 -1171.9270267717764 -1246.5949480280567 -1053.2524897821747
# 8 -1198.693278338197 -1446.3358301593455 -1106.4297476946067
# 9 -1273.3827878036593 -1750.6591773262983 -1124.9396890867088
# 10 -1203.8842876857068 -1382.2538406153244 -1139.5779027351948
# 11 -1223.5620047725724 -1853.7397622940798 -1021.4176695299618
# 12 -1240.9894851174731 -1346.1805536332645 -1147.187343782435
# 13 -1231.4447556043324 -1312.0818846702875 -1114.2986034309984
# 14 -1228.4327637759734 -1440.5943857340262 -1136.046301032978
# ...

# %%
visualize_episode_return(episode_returns)
